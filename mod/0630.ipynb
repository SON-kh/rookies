# %% [markdown]
# 2026.06.30

# %% [markdown]
# 데이터 수집

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\ez\appdata\local\programs\python\python312\lib\site-packages (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ez\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ez\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\ez\appdata\local\programs\python\python312\lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\ez\appdata\local\programs\python\python312\lib\site-packages (from requests) (2026.6.17)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

# %%
# 요청 URL
url =  'https://jsonplaceholder.typicode.com/posts'

# %%
# 요청 : read => get
response = requests.get(url)

# %%
type(response)
# Out:
# requests.models.Response

# %%
response.status_code
# Out:
# 200

# %%
if response.status_code == 200:
    print('OK')
    print(response.text[:500])
else:
    print('error', response.status_code)
# Out:
# OK
# [
#   {
#     "userId": 1,
#     "id": 1,
#     "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
#     "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
#   },
#   {
#     "userId": 1,
#     "id": 2,
#     "title": "qui est esse",
#     "body": "est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate p

# %%
#JSON(text) => object
data_obj = response.json()
type(data_obj)
# Out:
# list

# %%
for post in data_obj:
    print(post.get('title'))
    print(post['body'][:10])
    print('_'*20)
# Out:
# sunt aut facere repellat provident occaecati excepturi optio reprehenderit
# quia et su
# ____________________
# qui est esse
# est rerum
# ____________________
# ea molestias quasi exercitationem repellat qui ipsa sit aut
# et iusto s
# ____________________
# eum et est occaecati
# ullam et s
# ____________________
# nesciunt quas odio
# repudianda
# ____________________
# dolorem eum magni eos aperiam quia
# ut asperna
# ____________________
# magnam facilis autem
# dolore pla
# ____________________
# dolorem dolore est ipsam
# dignissimo
# ____________________
# nesciunt iure omnis dolorem tempora et accusantium
# consectetu
# ____________________
# optio molestias id quia eum
# quo et exp
# ____________________
# et ea vero quia laudantium autem
# delectus r
# ____________________
# in quibusdam tempore odit est dolorem
# itaque id
# ____________________
# dolorum ut in voluptas mollitia et saepe quo animi
# aut dicta
# ____________________
# voluptatem eligendi optio
# fuga et ac
# ____________________
# eveniet quod temporibus
# reprehende
# ____________________
# sint suscipit perspiciatis velit dolorum rerum ipsa laboriosam odio
# suscipit n
# ____________________
# fugit voluptas sed molestias voluptatem provident
# eos volupt
# ____________________
# voluptate et itaque vero tempora molestiae
# eveniet qu
# ____________________
# adipisci placeat illum aut reiciendis qui
# illum quis
# ____________________
# doloribus ad provident suscipit at
# qui conseq
# ____________________
# asperiores ea ipsam voluptatibus modi minima quia sint
# repellat a
# ____________________
# dolor sint quo a velit explicabo quia nam
# eos qui et
# ____________________
# maxime id vitae nihil numquam
# veritatis
# ____________________
# autem hic labore sunt dolores incidunt
# enim et ex
# ____________________
# rem alias distinctio quo quis
# ullam cons
# ____________________
# est et quae odit qui non
# similique
# ____________________
# quasi id et eos tenetur aut quo autem
# eum sed do
# ____________________
# delectus ullam et corporis nulla voluptas sequi
# non et qua
# ____________________
# iusto eius quod necessitatibus culpa ea
# odit magna
# ____________________
# a quo magni similique perferendis
# alias dolo
# ____________________
# ullam ut quidem id aut vel consequuntur
# debitis ei
# ____________________
# doloremque illum aliquid sunt
# deserunt e
# ____________________
# qui explicabo molestiae dolorem
# rerum ut e
# ____________________
# magnam ut rerum iure
# ea velit p
# ____________________
# id nihil consequatur molestias animi provident
# nisi error
# ____________________
# fuga nam accusamus voluptas reiciendis itaque
# ad molliti
# ____________________
# provident vel ut sit ratione est
# debitis et
# ____________________
# explicabo et eos deleniti nostrum ab id repellendus
# animi esse
# ____________________
# eos dolorem iste accusantium est eaque quam
# corporis r
# ____________________
# enim quo cumque
# ut volupta
# ____________________
# non est facere
# molestias
# ____________________
# commodi ullam sint et excepturi error explicabo praesentium voluptas
# odio fugit
# ____________________
# eligendi iste nostrum consequuntur adipisci praesentium sit beatae perferendis
# similique
# ____________________
# optio dolor molestias sit
# temporibus
# ____________________
# ut numquam possimus omnis eius suscipit laudantium iure
# est natus
# ____________________
# aut quo modi neque nostrum ducimus
# voluptatem
# ____________________
# quibusdam cumque rem aut deserunt
# voluptatem
# ____________________
# ut voluptatem illum ea doloribus itaque eos
# voluptates
# ____________________
# laborum non sunt aut ut assumenda perspiciatis voluptas
# inventore
# ____________________
# repellendus qui recusandae incidunt voluptates tenetur qui omnis exercitationem
# error susc
# ____________________
# soluta aliquam aperiam consequatur illo quis voluptas
# sunt dolor
# ____________________
# qui enim et consequuntur quia animi quis voluptate quibusdam
# iusto est
# ____________________
# ut quo aut ducimus alias
# minima har
# ____________________
# sit asperiores ipsam eveniet odio non quia
# totam corp
# ____________________
# sit vel voluptatem et non libero
# debitis ex
# ____________________
# qui et at rerum necessitatibus
# aut est om
# ____________________
# sed ab est est
# at pariatu
# ____________________
# voluptatum itaque dolores nisi et quasi
# veniam vol
# ____________________
# qui commodi dolor at maiores et quis id accusantium
# perspiciat
# ____________________
# consequatur placeat omnis quisquam quia reprehenderit fugit veritatis facere
# asperiores
# ____________________
# voluptatem doloribus consectetur est ut ducimus
# ab nemo op
# ____________________
# beatae enim quia vel
# enim asper
# ____________________
# voluptas blanditiis repellendus animi ducimus error sapiente et suscipit
# enim adipi
# ____________________
# et fugit quas eum in in aperiam quod
# id velit b
# ____________________
# consequatur id enim sunt et et
# voluptatib
# ____________________
# repudiandae ea animi iusto
# officia ve
# ____________________
# aliquid eos sed fuga est maxime repellendus
# reprehende
# ____________________
# odio quis facere architecto reiciendis optio
# magnam mol
# ____________________
# fugiat quod pariatur odit minima
# officiis e
# ____________________
# voluptatem laborum magni
# sunt repel
# ____________________
# et iusto veniam et illum aut fuga
# occaecati
# ____________________
# sint hic doloribus consequatur eos non id
# quam occae
# ____________________
# consequuntur deleniti eos quia temporibus ab aliquid at
# voluptatem
# ____________________
# enim unde ratione doloribus quas enim ut sit sapiente
# odit qui e
# ____________________
# dignissimos eum dolor ut enim et delectus in
# commodi no
# ____________________
# doloremque officiis ad et non perferendis
# ut animi f
# ____________________
# necessitatibus quasi exercitationem odio
# modi ut in
# ____________________
# quam voluptatibus rerum veritatis
# nobis faci
# ____________________
# pariatur consequatur quia magnam autem omnis non amet
# libero acc
# ____________________
# labore in ex et explicabo corporis aut quas
# ex quod do
# ____________________
# tempora rem veritatis voluptas quo dolores vero
# facere qui
# ____________________
# laudantium voluptate suscipit sunt enim enim
# ut libero
# ____________________
# odit et voluptates doloribus alias odio et
# est molest
# ____________________
# optio ipsam molestias necessitatibus occaecati facilis veritatis dolores aut
# sint moles
# ____________________
# dolore veritatis porro provident adipisci blanditiis et sunt
# similique
# ____________________
# placeat quia et porro iste
# quasi exce
# ____________________
# nostrum quis quasi placeat
# eos et mol
# ____________________
# sapiente omnis fugit eos
# consequatu
# ____________________
# sint soluta et vel magnam aut ut sed qui
# repellat a
# ____________________
# ad iusto omnis odit dolor voluptatibus
# minus omni
# ____________________
# aut amet sed
# libero vol
# ____________________
# ratione ex tenetur perferendis
# aut et exc
# ____________________
# beatae soluta recusandae
# dolorem qu
# ____________________
# qui qui voluptates illo iste minima
# aspernatur
# ____________________
# id minus libero illum nam ad officiis
# earum volu
# ____________________
# quaerat velit veniam amet cupiditate aut numquam ut sequi
# in non odi
# ____________________
# quas fugiat ut perspiciatis vero provident
# eum non bl
# ____________________
# laboriosam dolor voluptates
# doloremque
# ____________________
# temporibus sit alias delectus eligendi possimus magni
# quo deleni
# ____________________
# at nam consequatur ea labore ea harum
# cupiditate
# ____________________

# %%
url = 'https://jsonplaceholder.typicode.com/posts/1'

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\ez\appdata\local\programs\python\python312\lib\site-packages (4.15.0)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\ez\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\ez\appdata\roaming\python\python312\site-packages (from beautifulsoup4) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# html 파싱

# %%
from bs4 import BeautifulSoup

# %%
html_doc = """
<html>
    <head>
        <title>Example Page</title>
    </head>
    <body>
        <h1>Welcome to Web Scraping</h1>
        <p class="description">This is an example paragraph.</p>
        <a href="https://example.com1">Visit Example1</a>
        <a href="https://example.com2">Visit Example2</a>
        <a href="https://example.com3">Visit Example3</a>
        <a href="https://example.com4">Visit Example4</a>
    </body>
</html>
"""

# %%
soup = BeautifulSoup(html_doc, 'html.parser')

# %%
print(soup.title)
print(soup.title.string)
print(soup.h1)
print(soup.h1.string)
print(soup.a)
print(soup.a.string)
print(soup.a['href'])
# Out:
# <title>Example Page</title>
# Example Page
# <h1>Welcome to Web Scraping</h1>
# Welcome to Web Scraping
# <a href="https://example.com1">Visit Example1</a>
# Visit Example1
# https://example.com1

# %%
# find(tag), find_all(tag)
a_tag = soup.find('a')
print(a_tag)
a_tags = soup.find_all('a')
print(a_tags)
# Out:
# <a href="https://example.com1">Visit Example1</a>
# [<a href="https://example.com1">Visit Example1</a>, <a href="https://example.com2">Visit Example2</a>, <a href="https://example.com3">Visit Example3</a>, <a href="https://example.com4">Visit Example4</a>]

# %%
links = []
for a_tag in a_tags:
    links.append(a_tag['href'])

print(links)
# Out:
# ['https://example.com1', 'https://example.com2', 'https://example.com3', 'https://example.com4']

# %%
# select(selector) => list
# select_one(selector) => tag
# clas="descrpition title big small"
# .discription {}
# .title {}
# .big {}
# .small {}
tag1 = soup.select_one('.description')
print(tag1)
tag2 = soup.select('.a')
print(tag2)
# Out:
# <p class="description">This is an example paragraph.</p>
# []

# %%
import requests

# %%
url = "https://news.ycombinator.com/"

# %%
res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
res.text[:100]
# Out:
# '<html lang="en" op="news"><head><meta name="referrer" content="origin"><meta name="viewport" content'

# %%
soup = BeautifulSoup(res.text, 'html.parser')

# %%
soup.find_all('a')
# Out:
# [<a href="https://news.ycombinator.com"><img height="18" src="y18.svg" style="border:1px white solid; display:block" width="18"/></a>,
#  <a href="news">Hacker News</a>,
#  <a href="newest">new</a>,
#  <a href="front">past</a>,
#  <a href="newcomments">comments</a>,
#  <a href="ask">ask</a>,
#  <a href="show">show</a>,
#  <a href="jobs">jobs</a>,
#  <a href="submit" rel="nofollow">submit</a>,
#  <a href="login?goto=news">login</a>,
#  <a href="vote?id=48683098&amp;how=up&amp;goto=news" id="up_48683098"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://opensourcelowtech.org/">Open Source Low Tech</a>,
#  <a href="from?site=opensourcelowtech.org"><span class="sitestr">opensourcelowtech.org</span></a>,
#  <a class="hnuser" href="user?id=grep_it">grep_it</a>,
#  <a href="item?id=48683098">3 hours ago</a>,
#  <a href="hide?id=48683098&amp;goto=news">hide</a>,
#  <a href="item?id=48683098">19 comments</a>,
#  <a href="vote?id=48721903&amp;how=up&amp;goto=news" id="up_48721903"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://quesma.com/blog/qwen-36-is-awesome/">Qwen 3.6 27B is the sweet spot for local development</a>,
#  <a href="from?site=quesma.com"><span class="sitestr">quesma.com</span></a>,
#  <a class="hnuser" href="user?id=stared">stared</a>,
#  <a href="item?id=48721903">15 hours ago</a>,
#  <a href="hide?id=48721903&amp;goto=news">hide</a>,
#  <a href="item?id=48721903">600 comments</a>,
#  <a href="vote?id=48724230&amp;how=up&amp;goto=news" id="up_48724230"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://hccf.onmy.cloud/2026/06/21/reclaiming-our-digital-selves-hccfs-vision-for-a-human-centered-top-level-domain/">.self: A new top-level domain designed to support self-hosting</a>,
#  <a href="from?site=onmy.cloud"><span class="sitestr">onmy.cloud</span></a>,
#  <a class="hnuser" href="user?id=HumanCCF">HumanCCF</a>,
#  <a href="item?id=48724230">12 hours ago</a>,
#  <a href="hide?id=48724230&amp;goto=news">hide</a>,
#  <a href="item?id=48724230">276 comments</a>,
#  <a href="vote?id=48698908&amp;how=up&amp;goto=news" id="up_48698908"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://weblog.rogueamoeba.com/2026/06/26/free-the-icons/">Free the Icons</a>,
#  <a href="from?site=rogueamoeba.com"><span class="sitestr">rogueamoeba.com</span></a>,
#  <a class="hnuser" href="user?id=zdw">zdw</a>,
#  <a href="item?id=48698908">11 hours ago</a>,
#  <a href="hide?id=48698908&amp;goto=news">hide</a>,
#  <a href="item?id=48698908">114 comments</a>,
#  <a href="vote?id=48727116&amp;how=up&amp;goto=news" id="up_48727116"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://longcat.chat/blog/longcat-2.0/">LongCat-2.0, a large-scale MoE model with 1.6T total and 48B Active</a>,
#  <a href="from?site=longcat.chat"><span class="sitestr">longcat.chat</span></a>,
#  <a class="hnuser" href="user?id=benjiro29">benjiro29</a>,
#  <a href="item?id=48727116">7 hours ago</a>,
#  <a href="hide?id=48727116&amp;goto=news">hide</a>,
#  <a href="item?id=48727116">36 comments</a>,
#  <a href="vote?id=48727177&amp;how=up&amp;goto=news" id="up_48727177"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://fil-c.org/context_switches">Memory Safe Context Switching</a>,
#  <a href="from?site=fil-c.org"><span class="sitestr">fil-c.org</span></a>,
#  <a class="hnuser" href="user?id=modeless">modeless</a>,
#  <a href="item?id=48727177">7 hours ago</a>,
#  <a href="hide?id=48727177&amp;goto=news">hide</a>,
#  <a href="item?id=48727177">23 comments</a>,
#  <a href="vote?id=48702320&amp;how=up&amp;goto=news" id="up_48702320"><div class="votearrow" title="upvote"></div></a>,
#  <a href="http://occ.sdf.org/">Old Computer Challenge</a>,
#  <a href="from?site=occ.sdf.org"><span class="sitestr">occ.sdf.org</span></a>,
#  <a class="hnuser" href="user?id=wrxd">wrxd</a>,
#  <a href="item?id=48702320">6 hours ago</a>,
#  <a href="hide?id=48702320&amp;goto=news">hide</a>,
#  <a href="item?id=48702320">15 comments</a>,
#  <a href="vote?id=48727323&amp;how=up&amp;goto=news" id="up_48727323"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://obsolescence.dev/pdp1-lisp-introduction.html">Exploring PDP-1 Lisp (1960)</a>,
#  <a href="from?site=obsolescence.dev"><span class="sitestr">obsolescence.dev</span></a>,
#  <a class="hnuser" href="user?id=ozymandiax">ozymandiax</a>,
#  <a href="item?id=48727323">7 hours ago</a>,
#  <a href="hide?id=48727323&amp;goto=news">hide</a>,
#  <a href="item?id=48727323">16 comments</a>,
#  <a href="vote?id=48719485&amp;how=up&amp;goto=news" id="up_48719485"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://investors.rocketlabcorp.com/news-releases/news-release-details/rocket-lab-acquire-iridium-historic-deal-creating-fully">Rocketlab acquires Iridium</a>,
#  <a href="from?site=rocketlabcorp.com"><span class="sitestr">rocketlabcorp.com</span></a>,
#  <a class="hnuser" href="user?id=everfrustrated">everfrustrated</a>,
#  <a href="item?id=48719485">18 hours ago</a>,
#  <a href="hide?id=48719485&amp;goto=news">hide</a>,
#  <a href="item?id=48719485">265 comments</a>,
#  <a href="vote?id=48728599&amp;how=up&amp;goto=news" id="up_48728599"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://marcin.juszkiewicz.com.pl/2026/06/26/the-end-of-the-aarch64-desktop-experiment/">The end of the AArch64 desktop experiment</a>,
#  <a href="from?site=juszkiewicz.com.pl"><span class="sitestr">juszkiewicz.com.pl</span></a>,
#  <a class="hnuser" href="user?id=signa11">signa11</a>,
#  <a href="item?id=48728599">3 hours ago</a>,
#  <a href="hide?id=48728599&amp;goto=news">hide</a>,
#  <a href="item?id=48728599">9 comments</a>,
#  <a href="vote?id=48728740&amp;how=up&amp;goto=news" id="up_48728740"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://noyb.eu/en/us-supreme-court-just-blew-eu-us-data-transfers">US Supreme Court Just Blew Up EU-US Data Transfers</a>,
#  <a href="from?site=noyb.eu"><span class="sitestr">noyb.eu</span></a>,
#  <a class="hnuser" href="user?id=tomwas54">tomwas54</a>,
#  <a href="item?id=48728740">3 hours ago</a>,
#  <a href="hide?id=48728740&amp;goto=news">hide</a>,
#  <a href="item?id=48728740">52 comments</a>,
#  <a href="vote?id=48720186&amp;how=up&amp;goto=news" id="up_48720186"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://github.com/LinuxMD/linuxmd">Linux for the Sega MegaDrive</a>,
#  <a href="from?site=github.com/linuxmd"><span class="sitestr">github.com/linuxmd</span></a>,
#  <a class="hnuser" href="user?id=HardwareLust">HardwareLust</a>,
#  <a href="item?id=48720186">9 hours ago</a>,
#  <a href="hide?id=48720186&amp;goto=news">hide</a>,
#  <a href="item?id=48720186">12 comments</a>,
#  <a href="vote?id=48728729&amp;how=up&amp;goto=news" id="up_48728729"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://moondream.ai/blog/popping-the-gpu-bubble">Popping the GPU Bubble</a>,
#  <a href="from?site=moondream.ai"><span class="sitestr">moondream.ai</span></a>,
#  <a class="hnuser" href="user?id=radq">radq</a>,
#  <a href="item?id=48728729">3 hours ago</a>,
#  <a href="hide?id=48728729&amp;goto=news">hide</a>,
#  <a href="item?id=48728729">20 comments</a>,
#  <a href="vote?id=48722052&amp;how=up&amp;goto=news" id="up_48722052"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://github.com/deepreinforce-ai/Ornith-1">Ornith-1.0: self-improving open-source models for agentic coding</a>,
#  <a href="from?site=github.com/deepreinforce-ai"><span class="sitestr">github.com/deepreinforce-ai</span></a>,
#  <a class="hnuser" href="user?id=danboarder">danboarder</a>,
#  <a href="item?id=48722052">15 hours ago</a>,
#  <a href="hide?id=48722052&amp;goto=news">hide</a>,
#  <a href="item?id=48722052">39 comments</a>,
#  <a href="vote?id=48698648&amp;how=up&amp;goto=news" id="up_48698648"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://cse.buffalo.edu/tech-reports/2014-04.pdf" rel="nofollow">Logical Physical Clocks and Consistent Snapshots in Globally Distributed DB [pdf]</a>,
#  <a href="from?site=buffalo.edu"><span class="sitestr">buffalo.edu</span></a>,
#  <a class="hnuser" href="user?id=teleforce">teleforce</a>,
#  <a href="item?id=48698648">1 hour ago</a>,
#  <a href="hide?id=48698648&amp;goto=news">hide</a>,
#  <a href="item?id=48698648">discuss</a>,
#  <a href="vote?id=48720924&amp;how=up&amp;goto=news" id="up_48720924"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://www.theguardian.com/us-news/2026/jun/29/supreme-court-geofence-warrants-case-decision">US Supreme Court rules geofence warrants require constitutional protections</a>,
#  <a href="from?site=theguardian.com"><span class="sitestr">theguardian.com</span></a>,
#  <a class="hnuser" href="user?id=cdrnsf">cdrnsf</a>,
#  <a href="item?id=48720924">16 hours ago</a>,
#  <a href="hide?id=48720924&amp;goto=news">hide</a>,
#  <a href="item?id=48720924">243 comments</a>,
#  <a href="vote?id=48706389&amp;how=up&amp;goto=news" id="up_48706389"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://www.theverge.com/tech/947157/passports-data-breach-cannabis-club-systems-nefos-puffpal">One million passports leaked online</a>,
#  <a href="from?site=theverge.com"><span class="sitestr">theverge.com</span></a>,
#  <a class="hnuser" href="user?id=jruohonen">jruohonen</a>,
#  <a href="item?id=48706389">21 hours ago</a>,
#  <a href="hide?id=48706389&amp;goto=news">hide</a>,
#  <a href="item?id=48706389">134 comments</a>,
#  <a href="vote?id=48679809&amp;how=up&amp;goto=news" id="up_48679809"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://ziglang.org/devlog/2026/#2026-06-26">Zig – SPIR-V Backend Progress</a>,
#  <a href="from?site=ziglang.org"><span class="sitestr">ziglang.org</span></a>,
#  <a class="hnuser" href="user?id=Retro_Dev">Retro_Dev</a>,
#  <a href="item?id=48679809">9 hours ago</a>,
#  <a href="hide?id=48679809&amp;goto=news">hide</a>,
#  <a href="item?id=48679809">20 comments</a>,
#  <a href="vote?id=48689885&amp;how=up&amp;goto=news" id="up_48689885"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://www.sqlite.org/howtocorrupt.html">How to corrupt an SQLite database file</a>,
#  <a href="from?site=sqlite.org"><span class="sitestr">sqlite.org</span></a>,
#  <a class="hnuser" href="user?id=tosh">tosh</a>,
#  <a href="item?id=48689885">7 hours ago</a>,
#  <a href="hide?id=48689885&amp;goto=news">hide</a>,
#  <a href="item?id=48689885">15 comments</a>,
#  <a href="vote?id=48698781&amp;how=up&amp;goto=news" id="up_48698781"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://notes.shixiangxi.com/en/docs/appendix/alan-kay-on-oop/">Alan Kay on the meaning of "object-oriented programming" (2003)</a>,
#  <a href="from?site=shixiangxi.com"><span class="sitestr">shixiangxi.com</span></a>,
#  <a class="hnuser" href="user?id=sxx0">sxx0</a>,
#  <a href="item?id=48698781">8 hours ago</a>,
#  <a href="hide?id=48698781&amp;goto=news">hide</a>,
#  <a href="item?id=48698781">17 comments</a>,
#  <a href="vote?id=48702825&amp;how=up&amp;goto=news" id="up_48702825"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://arxiv.org/abs/2606.22283">Apple Neural Engine: Architecture, Programming, and Performance</a>,
#  <a href="from?site=arxiv.org"><span class="sitestr">arxiv.org</span></a>,
#  <a class="hnuser" href="user?id=Jimmc414">Jimmc414</a>,
#  <a href="item?id=48702825">16 hours ago</a>,
#  <a href="hide?id=48702825&amp;goto=news">hide</a>,
#  <a href="item?id=48702825">22 comments</a>,
#  <a href="vote?id=48710325&amp;how=up&amp;goto=news" id="up_48710325"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://www.britishorigami.org/cp-lister-list/the-1955-exhibition-by-akira-yoshizawa/">British Origami: the 1955 exhibition by Akira Yoshizawa (2005)</a>,
#  <a href="from?site=britishorigami.org"><span class="sitestr">britishorigami.org</span></a>,
#  <a class="hnuser" href="user?id=dang">dang</a>,
#  <a href="item?id=48710325">7 hours ago</a>,
#  <a href="hide?id=48710325&amp;goto=news">hide</a>,
#  <a href="item?id=48710325">3 comments</a>,
#  <a href="vote?id=48720758&amp;how=up&amp;goto=news" id="up_48720758"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://probablymarcus.com/blocks/2026/06/28/native-graphical-shell-for-SSH.html">A native graphical shell for SSH</a>,
#  <a href="from?site=probablymarcus.com"><span class="sitestr">probablymarcus.com</span></a>,
#  <a class="hnuser" href="user?id=mrcslws">mrcslws</a>,
#  <a href="item?id=48720758">16 hours ago</a>,
#  <a href="hide?id=48720758&amp;goto=news">hide</a>,
#  <a href="item?id=48720758">159 comments</a>,
#  <a href="vote?id=48675653&amp;how=up&amp;goto=news" id="up_48675653"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://www.savingourstars.org/darkskylighting#whatisdarkskylighting">Dark Sky Lighting</a>,
#  <a href="from?site=savingourstars.org"><span class="sitestr">savingourstars.org</span></a>,
#  <a class="hnuser" href="user?id=alexandrehtrb">alexandrehtrb</a>,
#  <a href="item?id=48675653">21 hours ago</a>,
#  <a href="hide?id=48675653&amp;goto=news">hide</a>,
#  <a href="item?id=48675653">35 comments</a>,
#  <a href="vote?id=48720190&amp;how=up&amp;goto=news" id="up_48720190"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://humphri.es/blog/WATaBoy/">WATaBoy: JIT-Ing Game Boy Instructions to WASM Beats a Native Interpreter</a>,
#  <a href="from?site=humphri.es"><span class="sitestr">humphri.es</span></a>,
#  <a class="hnuser" href="user?id=energeticbark">energeticbark</a>,
#  <a href="item?id=48720190">17 hours ago</a>,
#  <a href="hide?id=48720190&amp;goto=news">hide</a>,
#  <a href="item?id=48720190">33 comments</a>,
#  <a href="vote?id=48718863&amp;how=up&amp;goto=news" id="up_48718863"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://fergusfinn.com/blog/what-happens-when-you-run-a-gpu-kernel/">What happens when you run a CUDA kernel?</a>,
#  <a href="from?site=fergusfinn.com"><span class="sitestr">fergusfinn.com</span></a>,
#  <a class="hnuser" href="user?id=mezark">mezark</a>,
#  <a href="item?id=48718863">19 hours ago</a>,
#  <a href="hide?id=48718863&amp;goto=news">hide</a>,
#  <a href="item?id=48718863">30 comments</a>,
#  <a href="vote?id=48697599&amp;how=up&amp;goto=news" id="up_48697599"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://github.com/mat-mgm/kb-prolog">Kb – Prolog Knowledge Base</a>,
#  <a href="from?site=github.com/mat-mgm"><span class="sitestr">github.com/mat-mgm</span></a>,
#  <a class="hnuser" href="user?id=triska">triska</a>,
#  <a href="item?id=48697599">10 hours ago</a>,
#  <a href="hide?id=48697599&amp;goto=news">hide</a>,
#  <a href="item?id=48697599">7 comments</a>,
#  <a href="vote?id=48726102&amp;how=up&amp;goto=news" id="up_48726102"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://arstechnica.com/ai/2026/06/south-korea-to-spend-1t-on-more-memory-chip-production-and-humanoid-robots/">South Korea to spend $1T on more memory chip production and humanoid robots</a>,
#  <a href="from?site=arstechnica.com"><span class="sitestr">arstechnica.com</span></a>,
#  <a class="hnuser" href="user?id=jnord">jnord</a>,
#  <a href="item?id=48726102">10 hours ago</a>,
#  <a href="hide?id=48726102&amp;goto=news">hide</a>,
#  <a href="item?id=48726102">141 comments</a>,
#  <a href="vote?id=48711981&amp;how=up&amp;goto=news" id="up_48711981"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://theintercept.com/2026/06/26/daniel-sanchez-estrada-zines-prairieland-free-speech/">30-year sentence for transporting zines is a five-alarm fire for free speech</a>,
#  <a href="from?site=theintercept.com"><span class="sitestr">theintercept.com</span></a>,
#  <a class="hnuser" href="user?id=xrd">xrd</a>,
#  <a href="item?id=48711981">1 day ago</a>,
#  <a href="hide?id=48711981&amp;goto=news">hide</a>,
#  <a href="item?id=48711981">331 comments</a>,
#  <a href="vote?id=48683475&amp;how=up&amp;goto=news" id="up_48683475"><div class="votearrow" title="upvote"></div></a>,
#  <a href="https://lucassifoni.info/blog/hiking-with-wallace/">Wallace the 6 inch f/2.8 telescope, building it, and hiking with it</a>,
#  <a href="from?site=lucassifoni.info"><span class="sitestr">lucassifoni.info</span></a>,
#  <a class="hnuser" href="user?id=chantepierre">chantepierre</a>,
#  <a href="item?id=48683475">15 hours ago</a>,
#  <a href="hide?id=48683475&amp;goto=news">hide</a>,
#  <a href="item?id=48683475">24 comments</a>,
#  <a class="morelink" href="?p=2" rel="next">More</a>,
#  <a href="newsguidelines.html">Guidelines</a>,
#  <a href="newsfaq.html">FAQ</a>,
#  <a href="lists">Lists</a>,
#  <a href="https://github.com/HackerNews/API">API</a>,
#  <a href="security.html">Security</a>,
#  <a href="https://www.ycombinator.com/legal/">Legal</a>,
#  <a href="https://www.ycombinator.com/apply/">Apply to YC</a>,
#  <a href="mailto:hn@ycombinator.com">Contact</a>]

# %%
for item in soup.find_all():
    href_text = item.get('href')
    title_text = item.get_text()
    if href_text:
        print(title_text, href_text)
# Out:
#  news.css?Ug1GY3B6Kr5c7uonNem9
#  y18.svg
#  rss
#  https://news.ycombinator.com
# Hacker News news
# new newest
# past front
# comments newcomments
# ask ask
# show show
# jobs jobs
# submit submit
# login login?goto=news
#  vote?id=48683098&how=up&goto=news
# Open Source Low Tech https://opensourcelowtech.org/
# opensourcelowtech.org from?site=opensourcelowtech.org
# grep_it user?id=grep_it
# 3 hours ago item?id=48683098
# hide hide?id=48683098&goto=news
# 19 comments item?id=48683098
#  vote?id=48721903&how=up&goto=news
# Qwen 3.6 27B is the sweet spot for local development https://quesma.com/blog/qwen-36-is-awesome/
# quesma.com from?site=quesma.com
# stared user?id=stared
# 15 hours ago item?id=48721903
# hide hide?id=48721903&goto=news
# 600 comments item?id=48721903
#  vote?id=48724230&how=up&goto=news
# .self: A new top-level domain designed to support self-hosting https://hccf.onmy.cloud/2026/06/21/reclaiming-our-digital-selves-hccfs-vision-for-a-human-centered-top-level-domain/
# onmy.cloud from?site=onmy.cloud
# HumanCCF user?id=HumanCCF
# 12 hours ago item?id=48724230
# hide hide?id=48724230&goto=news
# 276 comments item?id=48724230
#  vote?id=48698908&how=up&goto=news
# Free the Icons https://weblog.rogueamoeba.com/2026/06/26/free-the-icons/
# rogueamoeba.com from?site=rogueamoeba.com
# zdw user?id=zdw
# 11 hours ago item?id=48698908
# hide hide?id=48698908&goto=news
# 114 comments item?id=48698908
#  vote?id=48727116&how=up&goto=news
# LongCat-2.0, a large-scale MoE model with 1.6T total and 48B Active https://longcat.chat/blog/longcat-2.0/
# longcat.chat from?site=longcat.chat
# benjiro29 user?id=benjiro29
# 7 hours ago item?id=48727116
# hide hide?id=48727116&goto=news
# 36 comments item?id=48727116
#  vote?id=48727177&how=up&goto=news
# Memory Safe Context Switching https://fil-c.org/context_switches
# fil-c.org from?site=fil-c.org
# modeless user?id=modeless
# 7 hours ago item?id=48727177
# hide hide?id=48727177&goto=news
# 23 comments item?id=48727177
#  vote?id=48702320&how=up&goto=news
# Old Computer Challenge http://occ.sdf.org/
# occ.sdf.org from?site=occ.sdf.org
# wrxd user?id=wrxd
# 6 hours ago item?id=48702320
# hide hide?id=48702320&goto=news
# 15 comments item?id=48702320
#  vote?id=48727323&how=up&goto=news
# Exploring PDP-1 Lisp (1960) https://obsolescence.dev/pdp1-lisp-introduction.html
# obsolescence.dev from?site=obsolescence.dev
# ozymandiax user?id=ozymandiax
# 7 hours ago item?id=48727323
# hide hide?id=48727323&goto=news
# 16 comments item?id=48727323
#  vote?id=48719485&how=up&goto=news
# Rocketlab acquires Iridium https://investors.rocketlabcorp.com/news-releases/news-release-details/rocket-lab-acquire-iridium-historic-deal-creating-fully
# rocketlabcorp.com from?site=rocketlabcorp.com
# everfrustrated user?id=everfrustrated
# 18 hours ago item?id=48719485
# hide hide?id=48719485&goto=news
# 265 comments item?id=48719485
#  vote?id=48728599&how=up&goto=news
# The end of the AArch64 desktop experiment https://marcin.juszkiewicz.com.pl/2026/06/26/the-end-of-the-aarch64-desktop-experiment/
# juszkiewicz.com.pl from?site=juszkiewicz.com.pl
# signa11 user?id=signa11
# 3 hours ago item?id=48728599
# hide hide?id=48728599&goto=news
# 9 comments item?id=48728599
#  vote?id=48728740&how=up&goto=news
# US Supreme Court Just Blew Up EU-US Data Transfers https://noyb.eu/en/us-supreme-court-just-blew-eu-us-data-transfers
# noyb.eu from?site=noyb.eu
# tomwas54 user?id=tomwas54
# 3 hours ago item?id=48728740
# hide hide?id=48728740&goto=news
# 52 comments item?id=48728740
#  vote?id=48720186&how=up&goto=news
# Linux for the Sega MegaDrive https://github.com/LinuxMD/linuxmd
# github.com/linuxmd from?site=github.com/linuxmd
# HardwareLust user?id=HardwareLust
# 9 hours ago item?id=48720186
# hide hide?id=48720186&goto=news
# 12 comments item?id=48720186
#  vote?id=48728729&how=up&goto=news
# Popping the GPU Bubble https://moondream.ai/blog/popping-the-gpu-bubble
# moondream.ai from?site=moondream.ai
# radq user?id=radq
# 3 hours ago item?id=48728729
# hide hide?id=48728729&goto=news
# 20 comments item?id=48728729
#  vote?id=48722052&how=up&goto=news
# Ornith-1.0: self-improving open-source models for agentic coding https://github.com/deepreinforce-ai/Ornith-1
# github.com/deepreinforce-ai from?site=github.com/deepreinforce-ai
# danboarder user?id=danboarder
# 15 hours ago item?id=48722052
# hide hide?id=48722052&goto=news
# 39 comments item?id=48722052
#  vote?id=48698648&how=up&goto=news
# Logical Physical Clocks and Consistent Snapshots in Globally Distributed DB [pdf] https://cse.buffalo.edu/tech-reports/2014-04.pdf
# buffalo.edu from?site=buffalo.edu
# teleforce user?id=teleforce
# 1 hour ago item?id=48698648
# hide hide?id=48698648&goto=news
# discuss item?id=48698648
#  vote?id=48720924&how=up&goto=news
# US Supreme Court rules geofence warrants require constitutional protections https://www.theguardian.com/us-news/2026/jun/29/supreme-court-geofence-warrants-case-decision
# theguardian.com from?site=theguardian.com
# cdrnsf user?id=cdrnsf
# 16 hours ago item?id=48720924
# hide hide?id=48720924&goto=news
# 243 comments item?id=48720924
#  vote?id=48706389&how=up&goto=news
# One million passports leaked online https://www.theverge.com/tech/947157/passports-data-breach-cannabis-club-systems-nefos-puffpal
# theverge.com from?site=theverge.com
# jruohonen user?id=jruohonen
# 21 hours ago item?id=48706389
# hide hide?id=48706389&goto=news
# 134 comments item?id=48706389
#  vote?id=48679809&how=up&goto=news
# Zig – SPIR-V Backend Progress https://ziglang.org/devlog/2026/#2026-06-26
# ziglang.org from?site=ziglang.org
# Retro_Dev user?id=Retro_Dev
# 9 hours ago item?id=48679809
# hide hide?id=48679809&goto=news
# 20 comments item?id=48679809
#  vote?id=48689885&how=up&goto=news
# How to corrupt an SQLite database file https://www.sqlite.org/howtocorrupt.html
# sqlite.org from?site=sqlite.org
# tosh user?id=tosh
# 7 hours ago item?id=48689885
# hide hide?id=48689885&goto=news
# 15 comments item?id=48689885
#  vote?id=48698781&how=up&goto=news
# Alan Kay on the meaning of "object-oriented programming" (2003) https://notes.shixiangxi.com/en/docs/appendix/alan-kay-on-oop/
# shixiangxi.com from?site=shixiangxi.com
# sxx0 user?id=sxx0
# 8 hours ago item?id=48698781
# hide hide?id=48698781&goto=news
# 17 comments item?id=48698781
#  vote?id=48702825&how=up&goto=news
# Apple Neural Engine: Architecture, Programming, and Performance https://arxiv.org/abs/2606.22283
# arxiv.org from?site=arxiv.org
# Jimmc414 user?id=Jimmc414
# 16 hours ago item?id=48702825
# hide hide?id=48702825&goto=news
# 22 comments item?id=48702825
#  vote?id=48710325&how=up&goto=news
# British Origami: the 1955 exhibition by Akira Yoshizawa (2005) https://www.britishorigami.org/cp-lister-list/the-1955-exhibition-by-akira-yoshizawa/
# britishorigami.org from?site=britishorigami.org
# dang user?id=dang
# 7 hours ago item?id=48710325
# hide hide?id=48710325&goto=news
# 3 comments item?id=48710325
#  vote?id=48720758&how=up&goto=news
# A native graphical shell for SSH https://probablymarcus.com/blocks/2026/06/28/native-graphical-shell-for-SSH.html
# probablymarcus.com from?site=probablymarcus.com
# mrcslws user?id=mrcslws
# 16 hours ago item?id=48720758
# hide hide?id=48720758&goto=news
# 159 comments item?id=48720758
#  vote?id=48675653&how=up&goto=news
# Dark Sky Lighting https://www.savingourstars.org/darkskylighting#whatisdarkskylighting
# savingourstars.org from?site=savingourstars.org
# alexandrehtrb user?id=alexandrehtrb
# 21 hours ago item?id=48675653
# hide hide?id=48675653&goto=news
# 35 comments item?id=48675653
#  vote?id=48720190&how=up&goto=news
# WATaBoy: JIT-Ing Game Boy Instructions to WASM Beats a Native Interpreter https://humphri.es/blog/WATaBoy/
# humphri.es from?site=humphri.es
# energeticbark user?id=energeticbark
# 17 hours ago item?id=48720190
# hide hide?id=48720190&goto=news
# 33 comments item?id=48720190
#  vote?id=48718863&how=up&goto=news
# What happens when you run a CUDA kernel? https://fergusfinn.com/blog/what-happens-when-you-run-a-gpu-kernel/
# fergusfinn.com from?site=fergusfinn.com
# mezark user?id=mezark
# 19 hours ago item?id=48718863
# hide hide?id=48718863&goto=news
# 30 comments item?id=48718863
#  vote?id=48697599&how=up&goto=news
# Kb – Prolog Knowledge Base https://github.com/mat-mgm/kb-prolog
# github.com/mat-mgm from?site=github.com/mat-mgm
# triska user?id=triska
# 10 hours ago item?id=48697599
# hide hide?id=48697599&goto=news
# 7 comments item?id=48697599
#  vote?id=48726102&how=up&goto=news
# South Korea to spend $1T on more memory chip production and humanoid robots https://arstechnica.com/ai/2026/06/south-korea-to-spend-1t-on-more-memory-chip-production-and-humanoid-robots/
# arstechnica.com from?site=arstechnica.com
# jnord user?id=jnord
# 10 hours ago item?id=48726102
# hide hide?id=48726102&goto=news
# 141 comments item?id=48726102
#  vote?id=48711981&how=up&goto=news
# 30-year sentence for transporting zines is a five-alarm fire for free speech https://theintercept.com/2026/06/26/daniel-sanchez-estrada-zines-prairieland-free-speech/
# theintercept.com from?site=theintercept.com
# xrd user?id=xrd
# 1 day ago item?id=48711981
# hide hide?id=48711981&goto=news
# 331 comments item?id=48711981
#  vote?id=48683475&how=up&goto=news
# Wallace the 6 inch f/2.8 telescope, building it, and hiking with it https://lucassifoni.info/blog/hiking-with-wallace/
# lucassifoni.info from?site=lucassifoni.info
# chantepierre user?id=chantepierre
# 15 hours ago item?id=48683475
# hide hide?id=48683475&goto=news
# 24 comments item?id=48683475
# More ?p=2
# Guidelines newsguidelines.html
# FAQ newsfaq.html
# Lists lists
# API https://github.com/HackerNews/API
# Security security.html
# Legal https://www.ycombinator.com/legal/
# Apply to YC https://www.ycombinator.com/apply/
# Contact mailto:hn@ycombinator.com

# %% [markdown]
# 관계형 데이터 베이스 시스템 : RDBMS => SQLite

# %%
import sqlite3

# %%
# 데이터 베이스 연결
conn = sqlite3.connect('first.db')
print('데이터베이스 연결 성공')
conn.close
# Out:
# 데이터베이스 연결 성공
# <function Connection.close()>

# %%
import sqlite3
# 데이터베이스연결
connection = sqlite3.connect("example.db")
cursor = connection.cursor()
# SQL 명령어로테이블생성
cursor.execute("""
CREATE TABLE IF NOT EXISTS users (
id INTEGER PRIMARY KEY AUTOINCREMENT,
name TEXT NOT NULL,
age INTEGER,
city TEXT
)
""")
print("테이블이생성되었습니다!")
# 연결 종료
connection.close()
# Out:
# 테이블이생성되었습니다!

# %%
# 1. 데이터베이스 연결 => connection
conn = sqlite3.connect('first.db')
print('conn')
# Out:
# conn

# %%
# 2. sql 실행 객체 => Cursor
cursor = conn.cursor()

# %%
# 4. close
cursor.close
# Out:
# <function Cursor.close()>

# %%
sql_drop = 'drop table users'

# 데이터베이스 연결
connection = sqlite3.connect('example.db')

# cusor 
cursor = connection.cursor()

# sql 실행
cursor.execute(sql_drop)


connection.commit()
connection.close()

# %%
#행단위 검색
sql_select = 'select * from users'

conn = sqlite3.connect('first.db')
cursor = conn.cursor()
cursor.execute(sql_select)

# %%
rows = cursor.fetchall()

for row in rows:
    print(row)

conn.close
# Out:
# <function Connection.close()>

# %%
sql_update = 'update users set age=? where'

# %%
html_books = """
<div class='library'>
<div class='book' id='b-101'>
<h3 class='book-title'>딥러닝 텐서플로 마스터</h3>
<p class='book-author'>김작가</p>
</div>
<div class='book' id='b-102'>
<h3 class='book-title'>이것이 진짜 R 프로그래밍</h3>
<p class='book-author'>박통계</p>
</div>
<div class='book' id='b-103'>
<h3 class='book-title'>자연어 처리 입문</h3>
<p class='book-author'>최이과</p>
</div>
</div>
"""

# %%
from bs4 import BeautifulSoup

# BeautifulSoup 객체 생성
soup = BeautifulSoup(html_books, "html.parser")

# book 클래스가 있는 div 모두 찾기
books = soup.find_all("div", class_="book")

books_info = []

# 책 정보 추출
for book in books:

    # 제목
    title = book.find("h3", class_="book-title").text

    # 저자
    author = book.find("p", class_="book-author").text

    # 딕셔너리 형태로 저장
    books_info.append({
        "title": title,
        "author": author
    })

print("=== 추출된 도서 목록 ===")
print(books_info)
# Out:
# === 추출된 도서 목록 ===
# [{'title': '딥러닝 텐서플로 마스터', 'author': '김작가'}, {'title': '이것이 진짜 R 프로그래밍', 'author': '박통계'}, {'title': '자연어 처리 입문', 'author': '최이과'}]

# %%
html_news = """
<ul class='news-section'>
<li class='news-item'><a href='https://news.example.com/ai-1'>인공지능 규제법 통과, IT 업계 파장</a></li>
<li class='news-item'><a href='https://news.example.com/dev-2'>파이썬 3.12 릴리즈, 무엇이 달라졌나?</a></li>
<li class='news-item'><a href='https://news.example.com/sec-3'>오픈소스 라이브러리 보안 취약점 경고</a></li>
</ul>
"""

# %%
from bs4 import BeautifulSoup

# BeautifulSoup 객체 생성
soup = BeautifulSoup(html_news, "html.parser")

# 뉴스 목록 찾기
news = soup.find_all("li", class_="news-item")

news_list = []

# 뉴스 하나씩 반복
for item in news:

    # a 태그 찾기
    link = item.find("a")

    # 제목 추출
    headline = link.text

    # href 속성 추출
    url = link["href"]

    # 딕셔너리로 저장
    news_list.append({
        "headline": headline,
        "url": url
    })

print("=== 수집된 뉴스 헤드라인 ===")
print(news_list)
# Out:
# === 수집된 뉴스 헤드라인 ===
# [{'headline': '인공지능 규제법 통과, IT 업계 파장', 'url': 'https://news.example.com/ai-1'}, {'headline': '파이썬 3.12 릴리즈, 무엇이 달라졌나?', 'url': 'https://news.example.com/dev-2'}, {'headline': '오픈소스 라이브러리 보안 취약점 경고', 'url': 'https://news.example.com/sec-3'}]

# %%
import sqlite3

# 메모리 DB 연결
conn = sqlite3.connect(":memory:")

# Cursor 생성
cursor = conn.cursor()

# users 테이블 생성
cursor.execute("""
CREATE TABLE users(
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT,
    email TEXT,
    level TEXT
)
""")

# 회원 정보 입력
cursor.execute(
    "INSERT INTO users(name, email, level) VALUES(?, ?, ?)",
    ("홍길동", "hong@example.com", "gold")
)

cursor.execute(
    "INSERT INTO users(name, email, level) VALUES(?, ?, ?)",
    ("이영희", "lee@example.com", "silver")
)

cursor.execute(
    "INSERT INTO users(name, email, level) VALUES(?, ?, ?)",
    ("김철수", "kim@example.com", "gold")
)

# 저장
conn.commit()

# gold 회원 조회
cursor.execute(
    "SELECT name, email FROM users WHERE level = ?",
    ("gold",)
)

# 결과 저장
gold_users = cursor.fetchall()

print("=== Gold 등급 회원 목록 ===")
print(gold_users)

# 연결 종료
conn.close()
# Out:
# === Gold 등급 회원 목록 ===
# [('홍길동', 'hong@example.com'), ('김철수', 'kim@example.com')]

# %%
import pandas as pd
import sqlite3

# 실습 데이터프레임 생성
df_members = pd.DataFrame({
    "member_id": ["M01", "M02", "M03"],
    "name": ["이민수", "김영희", "박준형"],
    "score": [85, 95, 78]
})

# DB 연결
conn = sqlite3.connect("users.db")

# DataFrame을 members 테이블로 저장
df_members.to_sql(
    "members",
    conn,
    if_exists="replace",
    index=False
)

# 저장
conn.commit()

# 연결 종료
conn.close()

# 다시 DB 연결
conn = sqlite3.connect("users.db")

# SQL로 데이터 읽기
df_read = pd.read_sql_query(
    "SELECT * FROM members",
    conn
)

# 연결 종료
conn.close()

print("=== DB 복원 데이터프레임 ===")
print(df_read)
# Out:
# === DB 복원 데이터프레임 ===
#   member_id name  score
# 0       M01  이민수     85
# 1       M02  김영희     95
# 2       M03  박준형     78
